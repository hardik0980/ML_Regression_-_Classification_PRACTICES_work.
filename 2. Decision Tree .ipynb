# %% [markdown]
# # Decision tree

# %% [raw]
# Demo-Decision Tree using Python In this demo, you will learn how to apply decision tree algorithm in Python using sokill-leam library.¶
#
# Problem Statement The dataset contains information about 3 brands namely US, Japan, Europe. Other parameters are mpg nyinders, Cubifinches, tp, weightbs, time-to-60, year. The lask is to find the brand of a car using these parameters

# %% [markdown]
# # Importing Required Libraries¶

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score
from io import StringIO
# %matplotlib inline

# %%
Car_Data = pd.read_csv("cars.csv")
Car_Data.head()
# Out:
#     mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year     brand
# 0  14.0          8          350  165       4209          12  1972       US.
# 1  31.9          4           89   71       1925          14  1980   Europe.
# 2  17.0          8          302  140       3449          11  1971       US.
# 3  15.0          8          400  150       3761          10  1971       US.
# 4  30.5          4           98   63       2051          17  1978       US.

# %%
Car_Data.describe().T
# Out:
#              count         mean         std     min     25%     50%     75%  \
# mpg          261.0    23.144828    7.823570    10.0    16.9    22.0    28.8
# cylinders    261.0     5.590038    1.733310     3.0     4.0     6.0     8.0
# cubicinches  261.0   201.030651  108.853214    68.0   101.0   156.0   302.0
# hp           261.0   106.360153   40.499959    46.0    75.0    95.0   138.0
# weightlbs    261.0  3004.122605  856.129151  1613.0  2245.0  2835.0  3672.0
# time-to-60   261.0    15.547893    2.910625     8.0    14.0    16.0    17.0
# year         261.0  1976.819923    3.637696  1971.0  1974.0  1977.0  1980.0
#
#                 max
# mpg            46.6
# cylinders       8.0
# cubicinches   455.0
# hp            230.0
# weightlbs    4997.0
# time-to-60     25.0
# year         1983.0

# %%
Car_Data.shape
# Out:
# (261, 8)

# %%
# Checking Null Values
Car_Data.isnull().any()
# Out:
# mpg            False
# cylinders      False
# cubicinches    False
# hp             False
# weightlbs      False
# time-to-60     False
# year           False
# brand          False
# dtype: bool

# %%
# Encoding Target Variable

# Using LabelEncoder To Encode The Target Variable

lb = LabelEncoder()
lb.fit(Car_Data["brand"])
Car_Data["brand"]=lb.transform(Car_Data["brand"])
lb
# Out:
# LabelEncoder()

# %%
# Divide Features And Target Variables

#Divide The DataSet Into Independant And Depandent Variables

X=Car_Data.drop("brand",axis=1)
y=Car_Data["brand"]

# %%
# Training And Testing Set

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2) #20 Percentage

# %%
dt_car = DecisionTreeClassifier(criterion="entropy",splitter="best",max_features=3,max_depth=3)
dt_car.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, max_features=3)
